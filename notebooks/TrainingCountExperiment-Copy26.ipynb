# %% [markdown]
# # Training Count Experiment
# This notebook launches a series of training jobs using increasing training sample counts.
#
# The notebook is split into 2 sections
# 1. Launching all the training jobs for the experiment.
#     * Uses a basic monitoring loop to launch a maximum number of jobs concurrently
#     * Saves a yaml file with current status of all training jobs, can be used to restart job launching and monitoring in case of error.
# 2. Collecting and aggregating the results of the training runs.

# %% [markdown]
# # Launch Experiment Training Jobs

# %%
# Imports
import boto3
import functools
import math
import time
import yaml
import os

from datetime import datetime
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role, Session
from sagemaker.utils import name_from_base, base_from_name
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\zelinski1\AppData\Local\sagemaker\sagemaker\config.yaml

# %%
'''print( os.getenv('AWS_ROLE') )
print( os.getenv('WANDB_API_KEY'))
print( dir(os.environ) )
print( os.environ.items() )'''
# Out:
# "print( os.getenv('AWS_ROLE') )\nprint( os.getenv('WANDB_API_KEY'))\nprint( dir(os.environ) )\nprint( os.environ.items() )"

# %% [markdown]
# ## Experiment Parameters

# %%
# Used as the base for all training jobs to keep organized
#draw = 0
experiment_name = "c1_cln_c2_1176_c2_25_c2_218_c3_14_80_20_20".replace('_','-')
#experiment_name = "test-count-1"

# List of training counts to try
# For our training split file (split_file.json) which consists of 13446 images, a good spread might be [10   256   588  1037  1643  2461  3564  5054  7066  9781 13446]
# training_counts =  [13446] #[ 128,   256 ,  588 , 1037 , 1643 , 2461 , 3564, 13446 ] # [10, 100, 1000, -1] # -1 to use all images. 
# For our training split file (filtered_split_all_data.json) which consists of 8229 images
training_counts =  [128, 256, 512, 1024, 2048, 4096, 8229] # # -1 to use all images. 
training_counts = [-1] # -1 to use all images. 

# Number of training runs per training count.
# Increasing this number will give better idea of performance variability 
# at the cost of more compute
training_jobs_per_count = 1

# Flag to indicate if models should be trained for equivalent iterations
# If True, epochs is scaled per experiment such that all experiments train for the
# same number of iterations as a run with all training data.
normalize_training_iterations = True

# Maximum number of simultaneous training jobs
# This could be limited by compute capacity or account quota limits
max_concurrent_jobs = 20
poll_rate_minutes = 1  # How often to poll if capacity is available in minutes

# WandB Parameters
WANDB_API_KEY = os.getenv('WANDB_API_KEY')  # Add key here. Recommend not storing key in notebook in git.
wandb_project_name = "wandb-test-count-1"

# Bucket to use for model checkpointing
checkpoint_bucket = "mz-temp" or Session().default_bucket()
checkpoint_s3_uri = None

# %% [markdown]
# ## Model Parameters
# Model parameters are shared between experiment runs. For example, the model type, batch size, learning rate, and augmentations.

# %%
train_image_uri = "s3://baselabelinginfrastack-alllabeledimages/images_camp1_cln_camp2_1176_camp2_218_camp2_25_camp3_14"
train_mask_uri = "s3://baselabelinginfrastack-alllabeledimages/masks_camp1_cln_camp2_1176_camp2_218_camp2_25_camp3_14" 

#train_split_file_uri = "s3://baselabelinginfrastack-alllabeledimages/json_split_files/17k_dataset_cleaned_geometry_draw_{}.json".format(draw) # split_file.json" #File that will lock in which images will go to train, test, validation datasets.
#train_split_file_uri = "s3://baselabelinginfrastack-alllabeledimages/filtered_split_all_data.json" # split_file.json" #File that will lock in which images will go to train, test, validation datasets.
#train_split_file_uri = "s3://baselabelinginfrastack-alllabeledimages/split_file.json" # split_file.json" #File that will lock in which images will go to train, test, validation datasets.
train_split_file_uri = "s3://baselabelinginfrastack-alllabeledimages/json_split_files/c1_cln_c2_1176_c2_25_c2_218_c3_14_80_20_20.json"

metadata_s3_uri = ""

train_volume_size = 1 # Increase/decrease as needed to fit the dataset

#"ml.g5.12xlarge" #be sure to increase the batch size
instance_type = "ml.g6e.12xlarge" #"ml.g5.12xlarge" #"ml.g4dn.4xlarge" # "ml.g5.12xlarge" #"ml.g4dn.4xlarge"
pytorch_version = "2.2"
python_version = "py310"

# Using spot instances can provide savings, but there is no gaurantee of acquiring an instance for training
# and it can be interrupted at any time.
# For more details see:
# https://docs.aws.amazon.com/sagemaker/latest/dg/model-managed-spot-training.html
use_spot = False 

# Set the role arn here to be used if not using the default sagemaker role
role = os.getenv('AWS_ROLE')

# Number of training epochs
train_epochs = 25

# Set the warm pool duration equal to the polling rate.
# Will enable faster initialization of new jobs
warm_pool_duration = poll_rate_minutes * 60

# See the LaunchTrainingJob notebook for more details on hyperparameters below
# These will be shared between all experiment runs
hyperparameters = {
    "num_workers": 16,
    "model_name": "UNet",
    # Note, with Pytorch Lightning, this is a per GPU batch count. PL will create a batch per device
    # behind the scenes. No need to adjust if changing instances with different gpu counts. 
    # Recommend adjust if changes instances that have different GPU memory (e.g., p3.* -> p3dn.* -> p4d.* -> p4de.*)
    "batch_size": 12,
    "learning_rate": 1e-4,
    "lr_schedular": "cosine_warmup",
    "image_mode": "grayscale",
    "split_file": train_split_file_uri,
    "use_zero":"True", # Set this to False is using instance with a single (1) GPU (e.g. ml.g4.4xlarge)
    "use_amp": "True", 
    # Data Augmentation Parameters
    "image_size": 1200,
    "use_random_resize": "True",
    "use_random_rotation": "False",
    "color_jitter": 0.0,
    "center_crop": "True",
    "center_crop_size": 1200,
    "test_image_size": 1200,
    "test_batch_size": 1,
    "project_name": wandb_project_name,
    #"metadata_file": metadata_s3_uri,
}

metric_def = [
    {"Name": "train:loss", "Regex": "train_loss=(.*?)[,\]]"},
    {"Name": "val:loss", "Regex": "val_loss=(.*?)[,\]]"},
    {"Name": "learning_rate", "Regex": "lr=(.*?)[,\]]"},
    {"Name": "val:acc", "Regex": "val_acc=(.*?)[,\]]"},
    {"Name": "val:jaccard", "Regex": "val_jaccard=(.*?)[,\]]"},
    {"Name": "val:dice", "Regex": "val_dice=(.*?)[,\]]"},
    {"Name": "test:loss", "Regex": "test_loss[ ]*[^\x00-\x7F] (.*?)[^\x00-\x7F]"},
    {"Name": "test:acc", "Regex": "test_acc[ ]*[^\x00-\x7F] (.*?)[^\x00-\x7F]"},
    {"Name": "test:jaccard", "Regex": "test_jaccard[ ]*[^\x00-\x7F] (.*?)[^\x00-\x7F]"},
    {"Name": "test:dice", "Regex": "test_dice[ ]*[^\x00-\x7F] (.*?)[^\x00-\x7F]"},
]

# %%
#%run ../bin/create_data_splits.py --image_path "s3://image-segmentation-2k/images" --mask_path "s3://image-segmentation-2k/masks" --split_file "s3://image-segmentation-2k/split_file.json"

# %% [markdown]
# ## Training Job Helper Functions

# %%
def launch_training_job(
        job_name: str,
        train_count: int,
        train_image_uri: str,
        train_mask_uri: str,
        instance_type: str,
        train_volume_size: int,
        pytorch_version: str,
        python_version: str,
        role: str,
        hyperparameters: dict,
        train_epochs: int,
        warm_pool_duration: int,
        normalize_iterations: bool,
        max_train_count: int,
        wandb_api_key: str,
        checkpoint_bucket: str,
        use_spot: bool,
        checkpoint_s3_uri: str, 
):
    print( normalize_iterations )
    if normalize_iterations:
        max_iterations = (max_train_count // hyperparameters['batch_size']) * train_epochs
        epochs = math.ceil(max_iterations / (train_count // hyperparameters['batch_size']))
    else:
        epochs = train_epochs
        
    # Update hyperparameters
    hyperparameters["epochs"] = epochs
    hyperparameters["train_count"] = train_count
    hyperparameters["run_name"] = job_name
    
    if role is None:
        role = get_execution_role()

    if checkpoint_s3_uri is None: 
        checkpoint_s3_uri = f"s3://{checkpoint_bucket}/{job_name}/checkpoints"
    
    print( checkpoint_s3_uri )
    print( checkpoint_bucket )
    local_checkpoint_path = "/opt/ml/checkpoints"
    # Launch the training job
    estimator = PyTorch(
        entry_point="train.py",
        # Point to the repo root one level up,
        # this notebook is at {repo}/notebooks/LaunchTrainingJob.ipynb
        source_dir="../src/",  
        role=role,
        framework_version=pytorch_version,
        py_version=python_version,
        instance_count=1,
        instance_type= instance_type,
        train_volume_size=train_volume_size,
        hyperparameters=hyperparameters, 
        input_mode="File",
        metric_definitions=metric_def,
        environment={"WANDB_API_KEY": wandb_api_key},
        keep_alive_period_in_seconds=warm_pool_duration,
        checkpoint_s3_uri=checkpoint_s3_uri,
        checkpoint_local_path=local_checkpoint_path,
        use_spot_instances=use_spot,
        max_run=3*24*60*60,
    )
    estimator.fit(
        {"train_image": train_image_uri, "train_mask": train_mask_uri}, job_name=job_name, wait=False
    )

# Create helper to only need to pass job_name and count
launch_training_job_by_count = functools.partial(
    launch_training_job,
    train_image_uri=train_image_uri,
    train_mask_uri=train_mask_uri,
    instance_type=instance_type,
    train_volume_size=train_volume_size,
    pytorch_version=pytorch_version,
    python_version=python_version,
    role=role,
    hyperparameters=hyperparameters,
    train_epochs=train_epochs,
    warm_pool_duration=warm_pool_duration,
    normalize_iterations=normalize_training_iterations,
    max_train_count=max(training_counts),
    wandb_api_key=WANDB_API_KEY,
    checkpoint_bucket=checkpoint_bucket,
    use_spot=use_spot,
    checkpoint_s3_uri=checkpoint_s3_uri,
)

# %%
def get_training_jobs(exp_name: str, start_time: datetime):
    sm = boto3.client("sagemaker")
    jobs_list = sm.list_training_jobs(CreationTimeAfter=start_time, NameContains=exp_name)
    jobs = {
        job["TrainingJobName"]: job["TrainingJobStatus"] for job in jobs_list["TrainingJobSummaries"]
    }
    return jobs

def resume_from_checkpoint(bookkeeping_filename: str):
    with open(bookkeeping_filename, 'r') as fp:
        status = yaml.safe_load(fp)
    jobs_to_run = status["jobs_to_run"]
    jobs_in_progress = status["jobs_in_progress"]
    jobs_completed = status["jobs_completed"]
    start_time = datetime.fromisoformat(status["start_time"])
    experiment_name = status["experiment_name"]
    print( 'jobs in progress' )
    print( jobs_in_progress )
    # Move all in progress jobs back to the jobs_to_run queue
    sm = boto3.client("sagemaker")
    for job_name in jobs_in_progress:
        # Get the count from the prior run's hyperparameters
        job_desc =  sm.describe_training_job(TrainingJobName=job_name)
        jobs_to_run.append({
            "job_name": job_name,
            "train_count": int( job_desc["HyperParameters"]["train_count"] )
        })
    jobs_in_progress = set()
    # Update all jobs_to_run names to ensure no conflicts with existing names
    jobs_to_run = [
        {"job_name": name_from_base(base_from_name(job["job_name"])), "train_count": job["train_count"]}
        for job in jobs_to_run
    ]
    print( jobs_to_run )
    return jobs_to_run, jobs_in_progress, jobs_completed, experiment_name, start_time

# %% [markdown]
# ## Launch and Monitor Training Jobs

# %%
# Create all JobNames and Parameter Configs
# Use SageMaker's name_from_base function to ensure name is 1) less than 63 characters and 2) has a unique ending
jobs_to_run = []
for count in training_counts:
    for ind in range(training_jobs_per_count):
        job_name = f"{experiment_name}-{count}-it{ind}"
        jobs_to_run.append({
            "job_name": name_from_base(job_name, short=True),
            "train_count": count,
        })
print(f"Creating {len(jobs_to_run)} training jobs.")
# Out:
# Creating 1 training jobs.

# %%
# Bookkeeping data to keep track of which jobs are training, which are waiting and those that have completed
jobs_in_progress = set()
jobs_completed = []

# Enter the path to an existing status dump file to resume training progress
resume_from_experiment_run = None # "test-count-8-job-progress-2024-04-19T19-30-22.yaml"

if resume_from_experiment_run:
    (
        jobs_to_run,
        jobs_in_progress,
        jobs_completed,
        experiment_name,
        start_time
    ) = resume_from_checkpoint(resume_from_experiment_run)
    bookkeeping_filename = resume_from_experiment_run
else:
    start_time = datetime.now()
    bookkeeping_filename = f"{experiment_name}-job-progress-{start_time.isoformat(timespec='seconds')}.yaml".replace(":", "-")

'''print( 'jobs to run 2' )
print( jobs_to_run )
print( jobs_in_progress )
print( jobs_completed )'''
# Out:
# "print( 'jobs to run 2' )\nprint( jobs_to_run )\nprint( jobs_in_progress )\nprint( jobs_completed )"

# %%
print("Kicking off training jobs")
print(f"Bookkeeping file name: {bookkeeping_filename}")
print("Checkpoint bucket: {}".format(checkpoint_bucket))
# Launch up to max concurrent jobs and keep track of progress
failure_detected = False
while (len(jobs_to_run) + len(jobs_in_progress)) > 0:
    # Get list of all jobs associated with this run
    training_jobs = get_training_jobs(experiment_name, start_time)
    timestamp = datetime.now().isoformat(timespec='seconds')
    print(f"{timestamp} - Start - {len(jobs_to_run)} jobs remaining to run. {len(jobs_in_progress)} jobs are running.")
    
    # See if any of active jobs are completed
    for job_name, status in training_jobs.items():
        if job_name in jobs_in_progress and status in {"Failed", "Completed"}:
            if status == "Failed":
                # An error has occurred and we will stop launching jobs
                print(f"ERROR!! Job '{job_name}' has Failed! Stopping experiment")
                failure_detected = True
                break
            # If completed, move to the completed set
            print(f"\t - Job {job_name} has completed!")
            jobs_completed.append(job_name)
            jobs_in_progress.remove(job_name)
    if failure_detected:
        break
    # See what capacity we have left for launching new jobs
    capacity = max_concurrent_jobs - len(jobs_in_progress)
    for _ in range(capacity):
        if len(jobs_to_run) < 1:
            break
        job_kwargs = jobs_to_run.pop()
        launch_training_job_by_count(**job_kwargs)
        jobs_in_progress.add(job_kwargs["job_name"])
        print(f"\t - Launched training job {job_kwargs['job_name']}")

        
    # Save out the current experiment status
    #bookkeeping_uri = f"s3://{checkpoint_bucket}/{bookkeeping_filename}"
    #with open( bookkeeping_uri, 'w') as fp:
    with open(bookkeeping_filename, 'w') as fp:
        status = {
            "experiment_name": experiment_name,
            "start_time": start_time.isoformat(timespec="seconds"),
            "last_updated": datetime.now().isoformat(timespec="seconds"),
            "jobs_to_run": jobs_to_run,
            "jobs_in_progress": list(jobs_in_progress),
            "jobs_completed": jobs_completed,
        }
        yaml.dump(status, fp)
    
        
    print(f"{timestamp} - End - {len(jobs_to_run)} jobs remaining to run. {len(jobs_in_progress)} jobs are running.")
    # Sleep the thread for the specified wait time
    time.sleep(poll_rate_minutes * 60)

if failure_detected:
    print(f"{datetime.now().isoformat(timespec='seconds')} - Failure occurred during a training job. ")
else:
    print(f"{datetime.now().isoformat(timespec='seconds')} - All jobs completed!")
    print(f"Final bookkeeping file: {bookkeeping_filename}")
# Out:
# Kicking off training jobs
# Bookkeeping file name: c1-cln-c2-1176-c2-25-c2-218-c3-14-80-20-20-job-progress-2025-11-05T23-49-49.yaml
# Checkpoint bucket: mz-temp
# train_volume_size has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2025-11-05T23:49:50 - Start - 1 jobs remaining to run. 0 jobs are running.
# True
# s3://mz-temp/c1-cln-c2-1176-c2-25-c2-218-c3-14-80-20-20--1-it0-251105-2349/checkpoints
# mz-temp
# INFO:sagemaker.image_uris:image_uri is not presented, retrieving image_uri based on instance_type, framework etc.
# INFO:sagemaker:Creating training-job with name: c1-cln-c2-1176-c2-25-c2-218-c3-14-80-20-20--1-it0-251105-2349
# 	 - Launched training job c1-cln-c2-1176-c2-25-c2-218-c3-14-80-20-20--1-it0-251105-2349
# 2025-11-05T23:49:50 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:50:56 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:50:56 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:51:57 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:51:57 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:52:58 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:52:58 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:53:59 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:53:59 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:55:00 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:55:00 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:56:01 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:56:01 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:57:01 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:57:01 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:58:02 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:58:02 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:59:03 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-05T23:59:03 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:00:03 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:00:03 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:01:04 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:01:04 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:02:05 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:02:05 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:03:05 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:03:05 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:04:06 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:04:06 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:05:07 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:05:07 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:06:07 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:06:07 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:07:08 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:07:08 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:08:09 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:08:09 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:09:09 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:09:09 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:10:10 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:10:10 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:11:11 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:11:11 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:12:12 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:12:12 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:13:13 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:13:13 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:14:13 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:14:13 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:15:14 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:15:14 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:16:14 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:16:14 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:17:15 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:17:15 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:18:15 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:18:15 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:19:16 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:19:16 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:20:16 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:20:16 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:21:17 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:21:17 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:22:18 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:22:18 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:23:18 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:23:18 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:24:19 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:24:19 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:25:19 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:25:19 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:26:20 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:26:20 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:27:20 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:27:20 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:28:21 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:28:21 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:29:21 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:29:21 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:30:22 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:30:22 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:31:22 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:31:22 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:32:23 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:32:23 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:33:23 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:33:23 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:34:24 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:34:24 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:35:24 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:35:24 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:36:25 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:36:25 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:37:25 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:37:25 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:38:26 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:38:26 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:39:26 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:39:26 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:40:26 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:40:26 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:41:27 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:41:27 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:42:27 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:42:27 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:43:28 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:43:28 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:44:28 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:44:28 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:45:29 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:45:29 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:46:29 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:46:29 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:47:30 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:47:30 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:48:30 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:48:30 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:49:31 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:49:31 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:50:32 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:50:32 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:51:32 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:51:32 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:52:33 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:52:33 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:53:33 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:53:33 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:54:34 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:54:34 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:55:34 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:55:34 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:56:34 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:56:34 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:57:35 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:57:35 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:58:35 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:58:35 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:59:36 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T00:59:36 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:00:36 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:00:36 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:01:37 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:01:37 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:02:37 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:02:37 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:03:38 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:03:38 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:04:38 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:04:38 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:05:39 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:05:39 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:06:40 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:06:40 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:07:40 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:07:40 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:08:41 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:08:41 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:09:41 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:09:41 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:10:42 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:10:42 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:11:42 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:11:42 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:12:43 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:12:43 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:13:43 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:13:43 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:14:44 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:14:44 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:15:44 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:15:44 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:16:45 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:16:45 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:17:45 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:17:45 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:18:46 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:18:46 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:19:46 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:19:46 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:20:47 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:20:47 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:21:47 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:21:47 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:22:48 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:22:48 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:23:48 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:23:48 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:24:49 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:24:49 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:25:49 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:25:49 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:26:50 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:26:50 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:27:50 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:27:50 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:28:51 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:28:51 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:29:51 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:29:51 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:30:52 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:30:52 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:31:52 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:31:52 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:32:53 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:32:53 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:33:53 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:33:53 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:34:54 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:34:54 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:35:54 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:35:54 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:36:55 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:36:55 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:37:55 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:37:55 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:38:56 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:38:56 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:39:56 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:39:56 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:40:57 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:40:57 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:41:57 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:41:57 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:42:58 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:42:58 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:43:58 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:43:58 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:44:59 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:44:59 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:45:59 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:45:59 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:47:00 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:47:00 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:48:00 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:48:00 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:49:01 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:49:01 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:50:01 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:50:01 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:51:02 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:51:02 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:52:02 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:52:02 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:53:03 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:53:03 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:54:03 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:54:03 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:55:04 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:55:04 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:56:04 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:56:04 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:57:05 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:57:05 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:58:05 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:58:05 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:59:06 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T01:59:06 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T02:00:06 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T02:00:06 - End - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T02:01:07 - Start - 0 jobs remaining to run. 1 jobs are running.
# 2025-11-06T02:01:07 - End - 0 jobs remaining to run. 1 jobs are running.

# %% [markdown]
# # Aggregate Job Metrics
# We will utilize the metrics definition from the training jobs to parse the test metrics that appeared in the logs.
#
# We will utilize the bookkeeping file used during model training to retrieve all the relevant job names.

# %%
# Update seaborn, pandas and matplotlib
# !pip install --upgrade seaborn pandas matplotlib

# %%
# Draw visualizations
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

import boto3
import yaml

# %%
# Load the relevant bookkeeping file
#bookkeeping_filename = "test-count-1-job-progress-2024-04-04T16:10:44.yaml"

with open(bookkeeping_filename, "r") as fp:
    status = yaml.safe_load(fp)
jobs_completed = status["jobs_completed"]

# %%
# For each job, just boto3 to get training job info, specifically hyperparameters and metrics
sm = boto3.client("sagemaker")
metrics = []
for index, job_name in enumerate(jobs_completed):
    job_desc = sm.describe_training_job(TrainingJobName=job_name)
    # Get train count
    train_count = job_desc["HyperParameters"]["train_count"]
    # Grab metrics from the FinalMetricDataList
    final_metrics = {item['MetricName']: item["Value"] for item in job_desc["FinalMetricDataList"]}
    metrics.append({
        "train_count": int(train_count),
        # "id": index,
        "acc": final_metrics["test:acc"],
        "dice": final_metrics["test:dice"],
        "jaccard": final_metrics["test:jaccard"]
    })

# %%
# convert metrics to dataframe for convenience
metrics_df = pd.DataFrame(metrics)
fig, axes = plt.subplots(3, 1, sharex=True, squeeze=True, layout="constrained")
for metric_name, ax in zip(["acc", "dice", "jaccard"], axes):
    sns.lineplot(data=metrics_df, x="train_count", y=metric_name, ax=ax)
    ax.set_title(metric_name)
plt.show()

# %%
#Run custom training job. 
if False:
    cp = 's3://mz-temp/test-count-8-13446-it0-240419-1930/checkpoints/'
    job_kwargs = {'job_name': 'test-count-8-13446-it0-240419-1930-5', 'train_count': 13446, 'checkpoint_s3_uri': cp}
    launch_training_job_by_count(**job_kwargs)
